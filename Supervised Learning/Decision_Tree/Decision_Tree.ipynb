# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("diabetes.csv")
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X = data.drop(["Outcome"],axis=1)
y = data['Outcome']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_classifier = DecisionTreeClassifier()
dt_classifier.fit(X_train,y_train)

score = dt_classifier.score(X_train,y_train)
print("R-squared Train  :", score)

score = dt_classifier.score(X_test, y_test)
print("R-squared Test  :", score)

y_pred = dt_classifier.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE :",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train  : 1.0
# R-squared Test  : 0.7012987012987013
# MSE : 0.2987012987012987
# RMSE : 0.5465357250000211

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(dt_classifier,filled=True)
# Out:
# [Text(0.40168539325842695, 0.9705882352941176, 'X[1] <= 129.5\ngini = 0.449\nsamples = 537\nvalue = [354, 183]'),
#  Text(0.14712078651685392, 0.9117647058823529, 'X[5] <= 26.3\ngini = 0.329\nsamples = 357\nvalue = [283, 74]'),
#  Text(0.0449438202247191, 0.8529411764705882, 'X[5] <= 9.1\ngini = 0.06\nsamples = 97\nvalue = [94, 3]'),
#  Text(0.02247191011235955, 0.7941176470588235, 'X[0] <= 7.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.011235955056179775, 0.7352941176470589, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.033707865168539325, 0.7352941176470589, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.06741573033707865, 0.7941176470588235, 'X[6] <= 0.669\ngini = 0.022\nsamples = 91\nvalue = [90, 1]'),
#  Text(0.056179775280898875, 0.7352941176470589, 'gini = 0.0\nsamples = 76\nvalue = [76, 0]'),
#  Text(0.07865168539325842, 0.7352941176470589, 'X[6] <= 0.705\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.06741573033707865, 0.6764705882352942, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0898876404494382, 0.6764705882352942, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.24929775280898878, 0.8529411764705882, 'X[7] <= 27.5\ngini = 0.397\nsamples = 260\nvalue = [189, 71]'),
#  Text(0.14606741573033707, 0.7941176470588235, 'X[5] <= 45.4\ngini = 0.243\nsamples = 120\nvalue = [103, 17]'),
#  Text(0.12359550561797752, 0.7352941176470589, 'X[2] <= 12.0\ngini = 0.212\nsamples = 116\nvalue = [102, 14]'),
#  Text(0.11235955056179775, 0.6764705882352942, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1348314606741573, 0.6764705882352942, 'X[0] <= 7.0\ngini = 0.201\nsamples = 115\nvalue = [102, 13]'),
#  Text(0.12359550561797752, 0.6176470588235294, 'X[6] <= 1.272\ngini = 0.188\nsamples = 114\nvalue = [102, 12]'),
#  Text(0.10112359550561797, 0.5588235294117647, 'X[5] <= 30.95\ngini = 0.165\nsamples = 110\nvalue = [100, 10]'),
#  Text(0.0898876404494382, 0.5, 'gini = 0.0\nsamples = 43\nvalue = [43, 0]'),
#  Text(0.11235955056179775, 0.5, 'X[2] <= 53.0\ngini = 0.254\nsamples = 67\nvalue = [57, 10]'),
#  Text(0.08426966292134831, 0.4411764705882353, 'X[0] <= 2.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.07303370786516854, 0.38235294117647056, 'X[6] <= 0.566\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.06179775280898876, 0.3235294117647059, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.08426966292134831, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09550561797752809, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1404494382022472, 0.4411764705882353, 'X[6] <= 0.652\ngini = 0.203\nsamples = 61\nvalue = [54, 7]'),
#  Text(0.11797752808988764, 0.38235294117647056, 'X[4] <= 36.5\ngini = 0.15\nsamples = 49\nvalue = [45, 4]'),
#  Text(0.10674157303370786, 0.3235294117647059, 'X[3] <= 40.5\ngini = 0.32\nsamples = 20\nvalue = [16, 4]'),
#  Text(0
 0.5588235294117647, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.43820224719101125, 0.7352941176470589, 'X[0] <= 8.5\ngini = 0.472\nsamples = 42\nvalue = [16, 26]'),
#  Text(0.42696629213483145, 0.6764705882352942, 'X[2] <= 87.0\ngini = 0.5\nsamples = 33\nvalue = [16, 17]'),
#  Text(0.4157303370786517, 0.6176470588235294, 'X[1] <= 97.0\ngini = 0.477\nsamples = 28\nvalue = [11, 17]'),
#  Text(0.4044943820224719, 0.5588235294117647, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.42696629213483145, 0.5588235294117647, 'X[1] <= 116.5\ngini = 0.413\nsamples = 24\nvalue = [7, 17]'),
#  Text(0.4044943820224719, 0.5, 'X[6] <= 1.395\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.39325842696629215, 0.4411764705882353, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.4157303370786517, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.449438202247191, 0.5, 'X[4] <= 78.0\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.43820224719101125, 0.4411764705882353, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4606741573033708, 0.4411764705882353, 'X[3] <= 41.5\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.449438202247191, 0.38235294117647056, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.47191011235955055, 0.38235294117647056, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.43820224719101125, 0.6176470588235294, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.449438202247191, 0.6764705882352942, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.65625, 0.9117647058823529, 'X[5] <= 27.85\ngini = 0.478\nsamples = 180\nvalue = [71, 109]'),
#  Text(0.4943820224719101, 0.8529411764705882, 'X[1] <= 145.5\ngini = 0.375\nsamples = 36\nvalue = [27, 9]'),
#  Text(0.47191011235955055, 0.7941176470588235, 'X[7] <= 59.5\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.4606741573033708, 0.7352941176470589, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.48314606741573035, 0.7352941176470589, 'X[7] <= 61.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.47191011235955055, 0.6764705882352942, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4943820224719101, 0.6764705882352942, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5168539325842697, 0.7941176470588235, 'X[7] <= 25.5\ngini = 0.498\nsamples = 17\nvalue = [9, 8]'),
#  Text(0.5056179775280899, 0.7352941176470589, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5280898876404494, 0.7352941176470589, 'X[7] <= 62.0\ngini = 0.49\nsamples = 14\nvalue = [6, 8]'),
#  Text(0.5168539325842697, 0.6764705882352942, 'X[5] <= 27.0\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(0.4943820224719101, 0.6176470588235294, 'X[5] <= 22.15\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.48314606741573035, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5056179775280899, 0.5588235294117647, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.5393258426966292, 0.6176470588235294, 'X[2] <= 32.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5280898876404494, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.550561797752809, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5393258426966292, 0.6764705882352942, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8181179775280899, 0.8529411764705882, 'X[1] <= 158.5\ngini = 0.424\nsamples = 144\nvalue = [44, 100]'),
#  Text(0.6867977528089888, 0.7941176470588235, 'X[7] <= 30.5\ngini = 0.487\nsamples = 88\nvalue = [37, 51]'),
#  Text(0.6123595505617978, 0.7352941176470589, 'X[2] <= 23.0\ngini = 0.49\nsamples = 42\nvalue = [24, 18]'),
#  Text(0.601123595505618, 0.6764705882352942, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6235955056179775, 0.6764705882352942, 'X[2] <= 88.0\ngini = 0.465\nsamples = 38\nvalue = [24, 14]'),
#  Text(0.6123595505617978, 0.6176470588235294, 'X[2] <= 72.0\ngini = 0.444\nsamples = 36\nvalue = [24, 12]'),
#  Text(0.5730337078651685, 0.5588235294117647, 'X[5] <= 33.75\ngini = 0.5\nsamples = 20\nvalue = [10, 10]'),
#  Text(0.550561797752809, 0.5, 'X[5] <= 31.05\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.5393258426966292, 0.4411764705882353, 'X[6] <= 0.374\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.5280898876404494, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.550561797752809, 0.38235294117647056, 'X[2] <= 67.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.5393258426966292, 0.3235294117647059, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5617977528089888, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5617977528089888, 0.4411764705882353, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.5955056179775281, 0.5, 'X[6] <= 0.535\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.5842696629213483, 0.4411764705882353, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.6067415730337079, 0.4411764705882353, 'X[1] <= 136.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5955056179775281, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6179775280898876, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.651685393258427, 0.5588235294117647, 'X[1] <= 157.5\ngini = 0.219\nsamples = 16\nvalue = [14, 2]'),
#  Text(0.6404494382022472, 0.5, 'X[2] <= 85.5\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.6292134831460674, 0.4411764705882353, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.651685393258427, 0.4411764705882353, 'X[0] <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6404494382022472, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6629213483146067, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6629213483146067, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6348314606741573, 0.6176470588235294, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7612359550561798, 0.7352941176470589, 'X[5] <= 34.05\ngini = 0.405\nsamples = 46\nvalue = [13, 33]'),
#  Text(0.7078651685393258, 0.6764705882352942, 'X[2] <= 75.0\ngini = 0.49\nsamples = 21\nvalue = [9, 12]'),
#  Text(0.6966292134831461, 0.6176470588235294, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7191011235955056, 0.6176470588235294, 'X[6] <= 0.436\ngini = 0.415\nsamples = 17\nvalue = [5, 12]'),
#  Text(0.7078651685393258, 0.5588235294117647, 'X[3] <= 16.5\ngini = 0.496\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.6853932584269663, 0.5, 'X[5] <= 29.7\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.6741573033707865, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6966292134831461, 0.4411764705882353, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7303370786516854, 0.5, 'X[5] <= 28.15\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.7191011235955056, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7415730337078652, 0.4411764705882353, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.7303370786516854, 0.5588235294117647, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.8146067415730337, 0.6764705882352942, 'X[6] <= 1.088\ngini = 0.269\nsamples = 25\nvalue = [4, 21]'),
#  Text(0.7865168539325843, 0.6176470588235294, 'X[4] <= 306.5\ngini = 0.172\nsamples = 21\nvalue = [2, 19]'),
#  Text(0.7640449438202247, 0.5588235294117647, 'X[5] <= 44.6\ngini = 0.1\nsamples = 19\nvalue = [1, 18]'),
#  Text(0.7528089887640449, 0.5, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(0.7752808988764045, 0.5, 'X[5] <= 47.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7640449438202247, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7865168539325843, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8089887640449438, 0.5588235294117647, 'X[2] <= 73.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.797752808988764, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8202247191011236, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8426966292134831, 0.6176470588235294, 'X[4] <= 147.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.8314606741573034, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8539325842696629, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.949438202247191, 0.7941176470588235, 'X[6] <= 1.157\ngini = 0.219\nsamples = 56\nvalue = [7, 49]'),
#  Text(0.9213483146067416, 0.7352941176470589, 'X[6] <= 0.343\ngini = 0.147\nsamples = 50\nvalue = [4, 46]'),
#  Text(0.9101123595505618, 0.6764705882352942, 'X[7] <= 48.5\ngini = 0.332\nsamples = 19\nvalue = [4, 15]'),
#  Text(0.8876404494382022, 0.6176470588235294, 'X[1] <= 177.0\ngini = 0.219\nsamples = 16\nvalue = [2, 14]'),
#  Text(0.8764044943820225, 0.5588235294117647, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.898876404494382, 0.5588235294117647, 'X[1] <= 179.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.8876404494382022, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9101123595505618, 0.5, 'X[1] <= 187.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.898876404494382, 0.4411764705882353, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9213483146067416, 0.4411764705882353, 'X[3] <= 7.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9101123595505618, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9325842696629213, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9325842696629213, 0.6176470588235294, 'X[1] <= 184.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9213483146067416, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9438202247191011, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9325842696629213, 0.6764705882352942, 'gini = 0.0\nsamples = 31\nvalue = [0, 31]'),
#  Text(0.9775280898876404, 0.7352941176470589, 'X[3] <= 40.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.9662921348314607, 0.6764705882352942, 'X[1] <= 168.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.9550561797752809, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9775280898876404, 0.6176470588235294, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9887640449438202, 0.6764705882352942, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]')]

# %%
dt_classifier = DecisionTreeClassifier(criterion="entropy",max_depth=4)
dt_classifier.fit(X_train,y_train)

score = dt_classifier.score(X_train,y_train)
print("R-squared Train  :", score)

score = dt_classifier.score(X_test, y_test)
print("R-squared Test  :", score)

y_pred = dt_classifier.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE :",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train  : 0.7858472998137802
# R-squared Test  : 0.7792207792207793
# MSE : 0.22077922077922077
# RMSE : 0.4698714938993648

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(dt_classifier,filled=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn import tree
plt.figure(figsize=(20,15))
tree.plot_tree(dt_classifier,filled=True, class_names=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64
